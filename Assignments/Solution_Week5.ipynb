# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### STUDENT'S PERFORMANCE DATA ANALYSIS

# %%
#Import Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data gets loaded and stored in "data"
data=pd.read_csv(r"Z:\ABES_2YEAR\Student_performance_maths.csv")
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Classify variables by their type: quantitative vs. categorical

# %%
# It shows datatype of each attribute present in dataset
data.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# It shows all "object" type data
obj = data.select_dtypes(include=['object']).copy()
obj.head()
# Out:
#   school sex address famsize Pstatus     Mjob      Fjob  reason guardian  \
# 0     GP   F       U     GT3       A  at_home   teacher  course   mother
# 1     GP   F       U     GT3       T  at_home     other  course   father
# 2     GP   F       U     LE3       T  at_home     other   other   mother
# 3     GP   F       U     GT3       T   health  services    home   mother
# 4     GP   F       U     GT3       T    other     other    home   father
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0       yes     no   no         no     yes    yes       no       no
# 1        no    yes   no         no      no    yes      yes       no
# 2       yes     no  yes         no     yes    yes      yes       no
# 3        no    yes  yes        yes     yes    yes      yes      yes
# 4        no    yes  yes         no     yes    yes       no       no

# %%
# # It shows all "integer" type data
obj = data.select_dtypes(include=['int64']).copy()
obj.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# 1     1     1       3         4   5   5   6
# 2     2     3       3        10   7   8  10
# 3     1     1       5         2  15  14  15
# 4     1     2       5         4   6  10  10

# %% [markdown]
# ## Handle categorical variables with numerically coded values

# %%
# Changing categorical data into numerical value

# School
print("School")
print(data.school.unique())
data.loc[data['school']=='GP', 'school'] = 1
data.loc[data['school']=='MS', 'school'] = 2
print(data.school.unique())
print()

# Gender
print("Gender")
print(data.sex.unique())
data.loc[data['sex']=='M', 'sex'] = 1
data.loc[data['sex']=='F', 'sex'] = 2
print(data.sex.unique())
print()

# Address
print("Address")
print(data.address.unique())
data.loc[data['address']=='R', 'address'] = 1
data.loc[data['address']=='U', 'address'] = 2
print(data.address.unique())
print()

# Family Size
print("Family Size")
print(data.famsize.unique())
data.loc[data['famsize']=='LE3', 'famsize'] = 1
data.loc[data['famsize']=='GT3', 'famsize'] = 2
print(data.famsize.unique())
print()

# Parent Status
print("Parent Status")
print(data.Pstatus.unique())
data.loc[data['Pstatus']=='A', 'Pstatus'] = 1
data.loc[data['Pstatus']=='T', 'Pstatus'] = 2
print(data.Pstatus.unique())
print()

# Mother's Job Status
print("Mother's Job Status")
print(data.Mjob.unique())
data.loc[data['Mjob']=='teacher', 'Mjob'] = 5
data.loc[data['Mjob']=='services', 'Mjob'] = 4
data.loc[data['Mjob']=='health', 'Mjob'] = 3
data.loc[data['Mjob']=='other', 'Mjob'] = 2
data.loc[data['Mjob']=='at_home', 'Mjob'] = 1
print(data.Mjob.unique())
print()

# Father's Job Status
print("Father's Job Status")
print(data.Fjob.unique())
data.loc[data['Fjob']=='teacher', 'Fjob'] = 5
data.loc[data['Fjob']=='services', 'Fjob'] = 4
data.loc[data['Fjob']=='health', 'Fjob'] = 3
data.loc[data['Fjob']=='other', 'Fjob'] = 2
data.loc[data['Fjob']=='at_home', 'Fjob'] = 1
print(data.Fjob.unique())
print()

# Reasons
print("Reasons")
print(data.reason.unique())
data.loc[data['reason']=='reputation', 'reason'] = 4
data.loc[data['reason']=='course', 'reason'] = 3
data.loc[data['reason']=='home', 'reason'] = 2
data.loc[data['reason']=='other', 'reason'] = 1
print(data.reason.unique())
print()

# Guardians
print("Guardians")
print(data.guardian.unique())
data.loc[data['guardian']=='father', 'guardian'] = 3
data.loc[data['guardian']=='mother', 'guardian'] = 2
data.loc[data['guardian']=='other', 'guardian'] = 1
print(data.guardian.unique())
print()

# School Support
print("School Support")
print(data.schoolsup.unique())
data.loc[data['schoolsup']=='yes', 'schoolsup'] = 2
data.loc[data['schoolsup']=='no', 'schoolsup'] = 1
print(data.schoolsup.unique())
print()

# Family Support
print("Family Support")
print(data.famsup.unique())
data.loc[data['famsup']=='yes', 'famsup'] = 2
data.loc[data['famsup']=='no', 'famsup'] = 1
print(data.famsup.unique())
print()

# Paid
print("Paid")
print(data.paid.unique())
data.loc[data['paid']=='yes', 'paid'] = 2
data.loc[data['paid']=='no', 'paid'] = 1
print(data.paid.unique())
print()

# Activities
print("Activities")
print(data.activities.unique())
data.loc[data['activities']=='yes', 'activities'] = 2
data.loc[data['activities']=='no', 'activities'] = 1
print(data.activities.unique())
print()

# Nursery
print("Nursery")
print(data.nursery.unique())
data.loc[data['nursery']=='yes', 'nursery'] = 2
data.loc[data['nursery']=='no', 'nursery'] = 1
print(data.nursery.unique())
print()

# Higher Education
print("Higher Education")
print(data.higher.unique())
data.loc[data['higher']=='yes', 'higher'] = 2
data.loc[data['higher']=='no', 'higher'] = 1
print(data.higher.unique())
print()

# Internet
print("Internet")
print(data.internet.unique())
data.loc[data['internet']=='yes', 'internet'] = 2
data.loc[data['internet']=='no', 'internet'] = 1
print(data.internet.unique())
print()

# Relationship
print("Relationship")
print(data.romantic.unique())
data.loc[data['romantic']=='yes', 'romantic'] = 2
data.loc[data['romantic']=='no', 'romantic'] = 1
print(data.romantic.unique())
print()
# Out:
# School
# ['GP' 'MS']
# [1 2]
#
# Gender
# ['F' 'M']
# [2 1]
#
# Address
# ['U' 'R']
# [2 1]
#
# Family Size
# ['GT3' 'LE3']
# [2 1]
#
# Parent Status
# ['A' 'T']
# [1 2]
#
# Mother's Job Status
# ['at_home' 'health' 'other' 'services' 'teacher']
# [1 3 2 4 5]
#
# Father's Job Status
# ['teacher' 'other' 'services' 'health' 'at_home']
# [5 2 4 3 1]
#
# Reasons
# ['course' 'other' 'home' 'reputation']
# [3 1 2 4]
#
# Guardians
# ['mother' 'father' 'other']
# [2 3 1]
#
# School Support
# ['yes' 'no']
# [2 1]
#
# Family Support
# ['no' 'yes']
# [1 2]
#
# Paid
# ['no' 'yes']
# [1 2]
#
# Activities
# ['no' 'yes']
# [1 2]
#
# Nursery
# ['yes' 'no']
# [2 1]
#
# Higher Education
# ['yes' 'no']
# [2 1]
#
# Internet
# ['no' 'yes']
# [1 2]
#
# Relationship
# ['no' 'yes']
# [1 2]

# %% [markdown]
# ## Perform Univariate Analysis

# %%
col = ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'G1', 'G2', 'G3']

fig, ax = plt.subplots(len(col), figsize=(34,50))

for i, col_val in enumerate(col):
    sns.distplot(data[col_val], hist=True, ax=ax[i])
    ax[i].set_title(col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=10)
    ax[i].set_ylabel('Value', fontsize=10)

plt.show()

# %%
data.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# ## Perform Bivariate Analysis

# %%
a=sns.pairplot(data)
a.fig.set_size_inches(34,18)

# %% [markdown]
# ## Identify and Treat missing values

# %%
# It shows is there a null value in dataset taken
data.isnull().values.any()
# Out:
# False

# %%
# It shows how many null values are there in each column 
data.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ##  Dataset Outliers

# %%
col = ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'G1', 'G2', 'G3']
fig, ax = plt.subplots(len(col), figsize=(34,60))
for i, col_val in enumerate(col):
    sns.boxplot(y=data[col_val], ax=ax[i])
    ax[i].set_title('Box plot - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
# It is used to find the pairwise correlation of all columns in the dataframe
data.corr()
# Out:
#               school       sex       age   address   famsize   Pstatus  \
# school      1.000000  0.012286  0.377610 -0.279797 -0.064866  0.045923
# sex         0.012286  1.000000  0.028606  0.028504  0.089862 -0.023443
# age         0.377610  0.028606  1.000000 -0.146722 -0.037847  0.029598
# address    -0.279797  0.028504 -0.146722  1.000000 -0.072472 -0.042572
# famsize    -0.064866  0.089862 -0.037847 -0.072472  1.000000  0.149612
# Pstatus     0.045923 -0.023443  0.029598 -0.042572  0.149612  1.000000
# Medu       -0.133333 -0.078228 -0.163658  0.138804  0.043068 -0.123565
# Fedu       -0.079807 -0.034878 -0.163438  0.072178  0.058879 -0.088730
# Mjob       -0.078654 -0.170195 -0.092223  0.132193 -0.089913 -0.038143
# Fjob        0.029670 -0.038861 -0.050513  0.034430  0.067255  0.021051
# reason     -0.128238  0.087122 -0.040670 -0.084383 -0.017583  0.000992
# guardian   -0.011109 -0.071343 -0.290485  0.044512 -0.002718  0.108715
# ...

# %% [markdown]
# ## Correlation Graph

# %%
# A correlation matrix shows the correlation between different variables in a matrix setting.
corr = data.corr()
plt.figure(figsize=(33,33))
sns.heatmap(corr, annot=True, cmap="magma_r")
plt.title('Correlation Heatmap', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')
